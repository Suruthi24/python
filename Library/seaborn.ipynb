# %% [markdown]
# ### Seaborn

# %% [markdown]
# -Create beautiful statistical graphs more easily

# %%
"""
sns.histplot()       → Distribution
sns.countplot()      → Category counts
sns.barplot()        → Numerical comparison
sns.boxplot()        → Distribution + outliers
sns.scatterplot()    → Relationship
sns.lineplot()       → Trend
sns.heatmap()        → Correlation matrix
sns.pairplot()       → Multiple relationships
sns.violinplot()     → Distribution shape
sns.regplot()        → Relationship + regression line
"""

# %%
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
titanic = pd.read_csv("train_titanic.csv")

sns.countplot(data=titanic, x="Sex")
plt.show()

sns.histplot(data=titanic, x="Age")
plt.show()

sns.boxplot(data=titanic, x="Pclass", y="Fare")
plt.show()

sns.barplot(data=titanic, x="Sex", y="Survived")
plt.show()

sns.heatmap(titanic.corr(numeric_only=True), annot=True)
plt.show()
